# %% [markdown]
# # **Librerias**

# %%
 # Importamos las bibliotecas a utilizar
import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg as la
import math as math
from scipy.integrate import odeint, solve_ivp
from scipy import integrate, linalg

# Matplotlib mostrará los resultados en la Notebook de Jupyter
# %matplotlib inline

# %%
def Caso(A):
  print('A=\n',A,'\n')
  p=np.trace(A)
  q=la.det(A)
  d=p**2-4*q
  print("det(A)/q =",q)
  print("Traza(A)/p =",p)
  print("Delta =",d)
  eigvals, eigvecs = la.eig(A)
  print("eigvals =",eigvals)
  print("eigvecs =",eigvecs)

def Sol2x2(A):
  p=np.trace(A)
  q=la.det(A)
  d=p**2-4*q
  eigvals, eigvecs = la.eig(A)
  t = np.linspace(0, 10,  200) 
  c1c2 =[[1,1],[-1,-1],[1,-1],[-1,1],[1,2],[2,1]]
  fig=plt.figure(figsize=(5, 5))
  fig.suptitle('Espacio fase Ejercicio '+str(e)+'')
  plt.gca().set_aspect('equal', adjustable='box')
  if d>0 or d==0:
    # Caso A
    if d>0:
      print("Caso A")
    # Caso B
    if d==0:
      print("Caso B")
    eig1=eigvals[0].real
    eig2=eigvals[1].real
    for c1,c2 in c1c2:
      tx=[]
      ty=[]
      for i in t:
        x = c1*np.exp(eig1*i)*eigvecs[:,0]+c2*np.exp(eig2*i)*eigvecs[:,1]
        tx.extend([x[0]])
        ty.extend([x[1]])
      plt.plot(tx,ty,label=(c1,c2))
    # Ejes X y Y
    plt.axvline(x=0,color='black')
    plt.axhline(y=0,color='black')
    plt.legend()
    plt.show
  # Caso C
  if d<0:
    c1c2=[1,2,3,4]
    print("Se resuelve para caso C")
    B11=eigvecs[:,0].real
    B12=eigvecs[:,0].imag
    B21=eigvecs[:,1].real
    B22=eigvecs[:,1].imag
    alpha0=eigvals[0].real
    beta0=abs(eigvals[0].imag)
    alpha1=eigvals[1].real
    beta1=abs(eigvals[1].imag)
    for k in c1c2:
      for j in c1c2:
        tx=[]
        ty=[]
        for i in t:
            X=(k*(B11*np.cos(beta0*i)-B12*np.sin(beta0*i)))*math.exp(alpha0*i)+j*(B21*np.cos(beta1*i)+B22*np.sin(beta1*i))*math.exp(alpha1*i) 
            tx.extend([X[0].real])
            ty.extend([X[1].real])
        plt.plot(tx,ty)
    # Ejes X y Y
    plt.axvline(x=0,color='black') 
    plt.axhline(y=0,color='black') 
    plt.show

# %% [markdown]
# # **Ejercicios**

# %% [markdown]
# Por favor grafique en el espacio fase una familia de soluciones y determine el tipo de punto crítico de cada uno de los siguientes sistemas de ecuaciones.

# %% [markdown]
# ## **Ejercicio 1**

# %% [markdown]
# $$\begin{eqnarray*}
# \frac{d x}{d t} & = & y  \\
# \frac{d y}{dt } & = & -x   \\
# \end{eqnarray*}$$ \\
#
# $$\begin{eqnarray*}
# A=
# \begin{bmatrix}
# 0 & 1 \\
# -1 & 0
# \end{bmatrix}
# \end{eqnarray*}$$

# %%
# Definimos la matriz y resolvemos
e=1
A = np.array([[0,1],[-1,0]]) 
Caso(A)
Sol2x2(A)
# Out:
# A=
#  [[ 0  1]
#  [-1  0]]
#
# det(A)/q = 1.0
# Traza(A)/p = 0
# Delta = -4.0
# eigvals = [0.+1.j 0.-1.j]
# eigvecs = [[0.70710678+0.j         0.70710678-0.j        ]
#  [0.        +0.70710678j 0.        -0.70710678j]]
# Se resuelve para caso C

# %% [markdown]
# El punto crítico es de tipo **Centro**

# %% [markdown]
# ## **Ejercicio 2**

# %% [markdown]
# $$\begin{eqnarray*}
# \frac{d x}{d t} & = & y  \\
# \frac{d y}{dt } & = & x   \\
# \end{eqnarray*}$$ \\
#
# $$\begin{eqnarray*}
# A=
# \begin{bmatrix}
# 0 & 1 \\
# 1 & 0
# \end{bmatrix}
# \end{eqnarray*}$$

# %%
# Definimos la matriz y resolvemos
e=2
A = np.array([[0,1],[1,0]]) 
Caso(A)
Sol2x2(A)
# Out:
# A=
#  [[0 1]
#  [1 0]]
#
# det(A)/q = -1.0
# Traza(A)/p = 0
# Delta = 4.0
# eigvals = [ 1.+0.j -1.+0.j]
# eigvecs = [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]
# Caso A

# %% [markdown]
# Es un **Punto Silla**

# %% [markdown]
# ## **Ejercicio 3**

# %% [markdown]
# $$\begin{eqnarray*}
# \frac{d^2 x}{d t^2} + \omega_0^2 x & = & 0, \ \omega_0 > 0  \\
# \end{eqnarray*}$$
#
# $$\begin{eqnarray*}
# A=
# \begin{bmatrix}
# 0 & 1 \\
# -w_0^2 & 0
# \end{bmatrix}
# \end{eqnarray*}$$

# %%
# Valores iniciales
w0=[1,1.5,2]
e=3
for w in w0:
  print("w0="+str(w)+" se tiene la matriz:")
  A=np.array([[0,1],[-w**2,0]])
  print('[['+str(A[0,0])+','+str(A[0,1])+'],\n['+str(A[1,0])+','+str(A[1,1])+']]') ##################
  Caso(A)
  Sol2x2(A)
# Out:
# w0=1 se tiene la matriz:
# [[0,1],
# [-1,0]]
# A=
#  [[ 0  1]
#  [-1  0]]
#
# det(A)/q = 1.0
# Traza(A)/p = 0
# Delta = -4.0
# eigvals = [0.+1.j 0.-1.j]
# eigvecs = [[0.70710678+0.j         0.70710678-0.j        ]
#  [0.        +0.70710678j 0.        -0.70710678j]]
# Se resuelve para caso C
# w0=1.5 se tiene la matriz:
# [[0.0,1.0],
# [-2.25,0.0]]
# A=
#  [[ 0.    1.  ]
#  [-2.25  0.  ]]
#
# det(A)/q = 2.25
# Traza(A)/p = 0.0
# Delta = -9.0
# eigvals = [0.+1.5j 0.-1.5j]
# eigvecs = [[0.        -0.5547002j 0.        +0.5547002j]
#  [0.83205029+0.j        0.83205029-0.j       ]]
# Se resuelve para caso C
# w0=2 se tiene la matriz:
# [[0,1],
# [-4,0]]
# A=
#  [[ 0  1]
#  [-4  0]]
#
# det(A)/q = 4.0
# Traza(A)/p = 0
# Delta = -16.0
# eigvals = [0.+2.j 0.-2.j]
# eigvecs = [[0.        -0.4472136j 0.        +0.4472136j]
#  [0.89442719+0.j        0.89442719-0.j       ]]
# Se resuelve para caso C

# %% [markdown]
# Es un punto **Centro**

# %% [markdown]
# ## **Ejercicio 4**

# %% [markdown]
# $$\begin{eqnarray*}
# \frac{d x}{d t} & = & -2 x  \\
# \frac{d y}{dt } & = &  2 z  \\
# \frac{d z}{dt } & = &  - 2 y  \\
# \end{eqnarray*}$$ \\
#
#
# $$\begin{eqnarray*}
# A=
# \begin{bmatrix}
# -2 & 0 & 0 \\
# 0 & 0 & 2 \\
# 0 & -2 & 0
# \end{bmatrix}
# \end{eqnarray*}$$

# %%
# Definimos la matriz A
A=np.array([[-2,0,0],[0,0,2],[0,-2,0]])
Caso(A)
# Out:
# A=
#  [[-2  0  0]
#  [ 0  0  2]
#  [ 0 -2  0]]
#
# det(A)/q = -8.0
# Traza(A)/p = -2
# Delta = 36.0
# eigvals = [ 0.+2.j  0.-2.j -2.+0.j]
# eigvecs = [[ 0.        +0.j          0.        -0.j          1.        +0.j        ]
#  [-0.70710678+0.j         -0.70710678-0.j          0.        +0.j        ]
#  [ 0.        -0.70710678j  0.        +0.70710678j  0.        +0.j        ]]

# %%
eigvals, eigvecs = la.eig(A)
t = np.linspace(0, 25,  1000) 
c1c2 = np.array([1.,2.,3.,4.])
B11=eigvecs[:,0].real
B12=eigvecs[:,0].imag
B21=eigvecs[:,1].real
B22=eigvecs[:,1].imag
alpha0=eigvals[0].real
beta0=abs(eigvals[0].imag)
alpha1=eigvals[1].real
beta1=abs(eigvals[1].imag)
B31=eigvecs[:,2].real
va=eigvals[2].real
fig=plt.figure()
ax = plt.axes(projection ='3d')
for k in c1c2:
  tx=[]
  ty=[]
  tz=[]
  for i in t:
      X=(k*(B11*np.cos(beta0*i)-B12*np.sin(beta0*i)))*np.exp(alpha0*i)+(k*(B21*np.cos(beta1*i)+B22*np.sin(beta1*i)))*np.exp(alpha1*i)+k*np.exp(va*i)*B31
      tx.extend([X[0].real])
      ty.extend([X[1].real])
      tz.extend([X[2].real])
  ax.plot3D(tx, ty, tz)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# Punto crítico **Centro**

# %% [markdown]
# ## **Ejercicio 5**

# %% [markdown]
# $$\begin{eqnarray*}
# \frac{d x}{d t} & = & - x + z  \\
# \frac{d y}{dt } & = &  3 y  \\
# \frac{d z}{dt } & = &  - x - z \\
# \end{eqnarray*}$$ \\
#
#
# $$\begin{eqnarray*}
# A=
# \begin{bmatrix}
# -1 & 0 & 1 \\
# 0 & 3 & 0 \\
# -1 & 0 & -1
# \end{bmatrix}
# \end{eqnarray*}$$

# %%
# Definimos la matriz A
A=np.array([[-1,0,1],[0,3,0],[-1,0,-1]])
Caso(A)
# Out:
# A=
#  [[-1  0  1]
#  [ 0  3  0]
#  [-1  0 -1]]
#
# det(A)/q = 6.0
# Traza(A)/p = 1
# Delta = -23.0
# eigvals = [-1.+1.j -1.-1.j  3.+0.j]
# eigvecs = [[0.70710678+0.j         0.70710678-0.j         0.        +0.j        ]
#  [0.        +0.j         0.        -0.j         1.        +0.j        ]
#  [0.        +0.70710678j 0.        -0.70710678j 0.        +0.j        ]]

# %%
eigvals, eigvecs = la.eig(A)
t = np.linspace(0, 25,  1000) 
c1c2 = np.array([1.,2.,3.,4.]) 
B11=eigvecs[:,0].real
B12=eigvecs[:,0].imag
B21=eigvecs[:,1].real
B22=eigvecs[:,1].imag
alpha0=eigvals[0].real
beta0=abs(eigvals[0].imag)
alpha1=eigvals[1].real
beta1=abs(eigvals[1].imag)
B31=eigvecs[:,2].real
va=eigvals[2].real
fig=plt.figure()
ax = plt.axes(projection ='3d')
for k in c1c2:
  tx=[]
  ty=[]
  tz=[]
  for i in t:
      X=(k*(B11*np.cos(beta0*i)-B12*np.sin(beta0*i)))*np.exp(alpha0*i)+(k*(B21*np.cos(beta1*i)+B22*np.sin(beta1*i)))*np.exp(alpha1*i)+k*np.exp(va*i)*B31
      tx.extend([X[0].real])
      ty.extend([X[1].real])
      tz.extend([X[2].real])
  ax.plot3D(tx, ty, tz)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# El punto crítico es **Foco o espiral inestable**

# %% [markdown]
# # **Problemas de valor inicial**

# %%
def eig(Eigvalores,Einvectores):
  print('Eigenvalores')
  print('lambda1 = ', eva[0])
  print('lambda2 = ', eva[1])
  print(' ')
  print('Eigenvectores')
  print('v1 =',eve[0])
  print('v2 =',eve[1])

# %% [markdown]
# ## **Ejercicio 6**

# %% [markdown]
# $$\begin{eqnarray*}
# \frac{d x}{d t} & = & - x  \\
# \frac{d y}{dt } & = &  x + 2 y  \\
# x(0) = 0, & & y(0) = 3
# \end{eqnarray*}$$ \\
#
# $$\begin{eqnarray*}
# A=
# \begin{bmatrix}
# -1 & 0 \\
# 1 & 2
# \end{bmatrix}
# \end{eqnarray*}$$

# %%
# Se define la matriz A
A=np.array([[-1,0],[1,2]])
print('A=\n',A,'\n')
# Se define la matriz X
X=np.array([[0],[3]]) 
print('X=\n',X,'\n')

def dX_dt(X,t=0): # Se define la derivada de la matriz X con respecto a t
    A=np.array([[-1,0],[1,2]])
    return np.array([ A[0,0]*X[0] + A[0,1]*X[1] ,
                  A[1,0]*X[0]+A[1,1]*X[1]])
# Out:
# A=
#  [[-1  0]
#  [ 1  2]]
#
# X=
#  [[0]
#  [3]]

# %%
# Puntos críticos del sistema
X_f0 = np.array([0.,0.])
print('Punto crítico del sistema')
print('Punto crítico X_f0:', X_f0)
print(' ')
all(dX_dt(X_f0) == np.zeros(2) )
# Out:
# Punto crítico del sistema
# Punto crítico X_f0: [0. 0.]
# True

# %%
# Eigen Valor y Eigen Vector
eva, eve = la.eig(A)
eig(eva,eve)
# Out:
# Eigenvalores
# lambda1 =  (2+0j)
# lambda2 =  (-1+0j)
#
# Eigenvectores
# v1 = [0.        0.9486833]
# v2 = [ 1.         -0.31622777]

# %%
# Solución numérica
t = np.linspace(0, 5,  500)            
X0 = np.array([0, 3])                     
X, infodict = integrate.odeint(dX_dt, X0, t, full_output=True)
infodict['message']
# Out:
# 'Integration successful.'

# %%
# Solución en el plano fase
x,y=X.T
plt.plot(x, y, 'r')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.title('Solución X(t) en el plano fase')
plt.show()

# %% [markdown]
# ## **Ejercicio 7**

# %% [markdown]
# $$\begin{eqnarray*}
# \frac{d x}{d t} & = & 2 x + y  \\
# \frac{d y}{dt } & = &  x +  y  \\
# x(1) = 1, & & y(1) = 1
# \end{eqnarray*}$$ \\
#
# $$\begin{eqnarray*}
# A=
# \begin{bmatrix}
# 2 & 1 \\
# 1 & 1
# \end{bmatrix}
# \end{eqnarray*}$$

# %%
# Se define la matriz A
A=np.array([[2,1],[1,1]])
print('A=\n',A,'\n')
# Se define la matriz X
X=np.array([[1],[1]]) 
print('X=\n',X,'\n')

def dX_dt(X,t=0): # Se define la derivada de la matriz X con respecto a t
    A=np.array([[2,1],[1,1]])
    return np.array([ A[0,0]*X[0] + A[0,1]*X[1] ,
                  A[1,0]*X[0]+A[1,1]*X[1]])
# Out:
# A=
#  [[2 1]
#  [1 1]]
#
# X=
#  [[1]
#  [1]]

# %%
# Puntos críticos del sistema
X_f0 = np.array([0.,0.])
print('Punto crítico del sistema')
print('Punto crítico X_f0:', X_f0)
print(' ')
all(dX_dt(X_f0) == np.zeros(2) )
# Out:
# Punto crítico del sistema
# Punto crítico X_f0: [0. 0.]
# True

# %%
# Eigen Valor y Eigen Vector
eva, eve = la.eig(A)
eig(eva,eve)
# Out:
# Eigenvalores
# lambda1 =  (2.618033988749895+0j)
# lambda2 =  (0.3819660112501052+0j)
#
# Eigenvectores
# v1 = [ 0.85065081 -0.52573111]
# v2 = [0.52573111 0.85065081]

# %%
# Solución numérica
t = np.linspace(0, 5,  500)            
X0 = np.array([1, 1])                     
X, infodict = integrate.odeint(dX_dt, X0, t, full_output=True)
infodict['message']
# Out:
# 'Integration successful.'

# %%
# Solución en el plano fase
x,y=X.T
plt.plot(x, y, 'r')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.title('Solución X(t) en el plano fase')
plt.show()

# %% [markdown]
# ## **Ejercicio 8**

# %% [markdown]
# $$\begin{eqnarray*}
# \frac{d x}{d t} & = & A x  \\
# x(0) & = & (0,3) \\
# A & = & \begin{bmatrix}
# 0 & 3 \\
# 1 & -2 \\
# \end{bmatrix}
# \end{eqnarray*}$$

# %%
# Se define la matriz A
A=np.array([[0,3],[1,-2]])
print('A=\n',A,'\n')
# Se define la matriz X
X=np.array([[0],[3]]) 
print('X=\n',X,'\n')

def dX_dt(X,t=0): # Se define la derivada de la matriz X con respecto a t
    A=np.array([[0,3],[1,-2]])
    return np.array([ A[0,0]*X[0] + A[0,1]*X[1] ,
                  A[1,0]*X[0]+A[1,1]*X[1]])
# Out:
# A=
#  [[ 0  3]
#  [ 1 -2]]
#
# X=
#  [[0]
#  [3]]

# %%
# Puntos críticos del sistema
X_f0 = np.array([0.,0.])
print('Punto crítico del sistema')
print('Punto crítico X_f0:', X_f0)
print(' ')
all(dX_dt(X_f0) == np.zeros(2) )
# Out:
# Punto crítico del sistema
# Punto crítico X_f0: [0. 0.]
# True

# %%
# Eigen Valor y Eigen Vector
eva, eve = la.eig(A)
eig(eva,eve)
# Out:
# Eigenvalores
# lambda1 =  (1.0000000000000004+0j)
# lambda2 =  (-3+0j)
#
# Eigenvectores
# v1 = [ 0.9486833  -0.70710678]
# v2 = [0.31622777 0.70710678]

# %%
# Solución numérica
t = np.linspace(0, 5,  500)            
X0 = np.array([0, 3])                     
X, infodict = integrate.odeint(dX_dt, X0, t, full_output=True)
infodict['message']
# Out:
# 'Integration successful.'

# %%
# Solución en el plano fase
x,y=X.T
plt.plot(x, y, 'r')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.title('Solución X(t) en el plano fase')
plt.show()

# %% [markdown]
# ## **Ejercicio 9**

# %% [markdown]
# $$\begin{eqnarray*}
# \frac{d x}{d t} & = & A x  \\
# x(0) & = & (0,-b,b) \\
# A & = & \begin{bmatrix}
# 2 & 0 & 0 \\
# 0 & -1 & 0 \\
# 0 & 2 & -3 \\
# \end{bmatrix}
# \end{eqnarray*}$$

# %%
# Definimos la matriz A
A=np.array([[2,0,0],[0,-1,0],[0,2,-3]]) 
print('A=\n',A,'\n')
def dX_dt(X,t=0): # Se define la derivada de la matriz X con respecto a t
    A=np.array([[2,0,0],[0,-1,0],[0,2,-3]])
    return np.array([ A[0,0]*X[0] + A[0,1]*X[1]+ A[0,2]*X[2] ,
                  A[1,0]*X[0]+A[1,1]*X[1]+ A[1,2]*X[2],
                  A[2,0]*X[0]+A[2,1]*X[1]+ A[2,2]*X[2]])
# Out:
# A=
#  [[ 2  0  0]
#  [ 0 -1  0]
#  [ 0  2 -3]]

# %%
# Puntos críticos del sistema
X_f0 = np.array([0.,0.,0.])
print('Punto crítico del sistema')
print('Punto crítico X_f0:', X_f0)
print(' ')
all(dX_dt(X_f0) == np.zeros(3) )
# Out:
# Punto crítico del sistema
# Punto crítico X_f0: [0. 0. 0.]
# True

# %%
# Eigen Valor y Eigen Vector
eva, eve = la.eig(A)
eig(eva,eve)
# Out:
# Eigenvalores
# lambda1 =  (2+0j)
# lambda2 =  (-3+0j)
#
# Eigenvectores
# v1 = [1. 0. 0.]
# v2 = [0.         0.         0.70710678]

# %%
# Solución numérica

# Rango de tiempo
t = np.linspace(0, 5,  500)

for b in [1,2,3,4,5]:
  # Condiciones iniciales
  X0 =np.array([0.,-b,b])
  X, infodict = integrate.odeint(dX_dt, X0, t, full_output=True)
  infodict['message']
  fig = plt.figure()
  # Syntax para 3-D
  ax = plt.axes(projection ='3d')
  plt.xlabel('x');
  plt.ylabel('y');
  # Definiendo ejes
  x, y, z = X.T
  # Gráfica
  ax.plot3D(x, y, z)
  ax.set_title(('Solución en el espacio fase (x(t),y(t),z(t)) con X0=',X0))
  plt.show()

# %% [markdown]
# # **Ejercicio 10**

# %% [markdown]
# Se tiene el siguiente sistema de resortes acoplados con dos masas. \\
# ![Unknown.png](data:image/png;base64,...)
#
# El sistema esta sujeto del primer resorte de la izquierda. Cuando el sistema se deja en reposo, las longitudes de los resortes son $L_1$ y $L_2$.
# Las ecuaciones de movimiento estan dadas por las siguientes ecuaciones diferenciales acopladas:
# $$\begin{eqnarray*}
# m_1 x_1^{''} + b_1 x_1^{'}+k_1 (x_1-L_1)-k_2(x_2-x_1-L_2) & = & 0 \\
# m_2 x_2^{''} + b_2 x_2^{'}+k_2(x_2-x_1-L_2) & = & 0 \\
# \end{eqnarray*}$$
# Encuentre las soluciones como funciones de $t$ y grafíquelas, así como las trayectorias en el espacio fase.
# Suponga que $L_1=L_2=1$ y que las masas son iguales $m_1=m_2=1$.
# $$\begin{eqnarray*}
# (1)x_1^{''} + b_1 x_1^{'}+k_1 (x_1-1)-k_2(x_2-x_1-1) & = & 0 \\
# (1)
# (2) x_2^{''} + b_2 x_2^{'}+k_2(x_2-x_1-1) & = & 0 \\
# \end{eqnarray*}$$
# \ $$\begin{eqnarray*}
# x_1^{''} + b_1 x_1^{'} + k_1x_1-k_2(x_2-x_1)-k_1+k_2 & = & 0 \\
# x_2^{''} + b_2 x_2^{'} + k_2(x_2-x_1)-k_2 & = & 0 \\
# \end{eqnarray*}$$ \ $$\begin{eqnarray*}
# x_1^{''}  & = & - b_1 x_1^{'} - k_1x_1-k_2(x_2-x_1)+k_1-k_2 \\
# x_2^{''}  & = & - b_2 x_2^{'} - k_2(x_2-x_1)+k_2 \\
# \end{eqnarray*}$$ \ $$x_1'=x_3,x_2'=x_4$$ \ $$\frac{dx}{dt}=x_3$$$$\frac{dx_3}{dt}=- b_1 x_3 +(-k_1+k_2)x_1-k_2x_2+(k_1-k_2)$$$$\frac{dx_2}{dt}=x_4$$$$x_4=- b_2 x_4 - k_2x_2+k_2x_1+k_2$$
# $$\begin{eqnarray*}
# \frac{d\vec{x}}{dt}=\frac{d}{dt}
# \begin{bmatrix}
# x_1\\
# x_3\\
# x_2\\
# x_4\\
# \end{bmatrix} = & \begin{bmatrix}
# 0 & 1 & 0 & 0\\
# -k_1+k_2 & -b_1 & -k_2 & k_1-k_2\\
# 0 & 0 & 0 & 1\\
# k_2 & 0 & -k_2 & -b_2\\
# \end{bmatrix}\begin{bmatrix}
# x_1\\
# x_3\\
# x_2\\
# x_4\\
# \end{bmatrix}+\begin{bmatrix}
# 0\\
# k_1-k_2\\
# 0 \\
# k_2 \\
# \end{bmatrix}
# \end{eqnarray*}$$

# %% [markdown]
# ## **10.1**

# %% [markdown]
# Encuentre los eigenvalores del sistema y diga como son las soluciones.
# Tenemos la matriz: $$
# \begin{bmatrix}
# 0-\lambda & 1 & 0 & 0\\
# -k_1+k_2 & -b_1-\lambda & -k_2 & k_1-k_2\\
# 0 & 0 & 0-\lambda & 1\\
# k_2 & 0 & -k_2 & -b_2-\lambda\\
# \end{bmatrix}
# $$ cuyo determinante es: $$det=\lambda^3b_2+\lambda k_1b_2-\lambda k_2 b_2+\lambda^2b_1b_2+\lambda^4+\lambda^2k_1+\lambda k_2^2+k_1 k_2-\lambda k_1 k_2+\lambda k_2 b_1+\lambda^3 b_1 $$ \ $$det=\lambda^4+(b_1+b_2)\lambda^3+(k_1+b_1b_2)\lambda^2+\lambda(k_1b_2-k_2 b_2+k_2^2-k_1 k_2+ k_2 b_1) +k_1 k_2 $$ \ $$det=\lambda^4+(b_1+b_2)\lambda^3+(k_1+b_1b_2)\lambda^2+\lambda(k_1b_2+k_2(-b_2+k_2-k_1+b_1) ) +k_1 k_2 $$
# Siendo asi los eigenvalores del sistema las soluciones al sistema: $$\boldsymbol{\lambda^4+(b_1+b_2)\lambda^3+(k_1+b_1b_2)\lambda^2+\lambda(k_1b_2+k_2(-b_2+k_2-k_1+b_1) ) +k_1 k_2=0}$$ Siendo $k_1,k_2,b_1,b_2$ constantes del sistema especifico a estudiar.

# %% [markdown]
# ## **10.2**

# %% [markdown]
# Caso sin fricción. $b_1=b_2=0$, $k_1=6$, $k_2=4$, condiciones iniciales $(x_1(0), x_1^{'}(0), x_2(0), x_2^{'}(0))=(1,0,4,0)$

# %%
# Constantes
k1=6.
k2=4.
b1=0.
b2=b1

# Matriz
X=np.array([[0,1,0,0],[-k1-k2,-b1,k2,0],[0,0,0,1],[k2,0,-1*k2,-1*b2]])
print('La matriz es ')
print(X)

C=np.array([[0],[2],[0],[4]])
def dX_dt(X,t=0):
  return np.array([X[1], 
                   (-k1-k2)*X[0] -b1*X[1] +k2*X[2],  
                   X[3],   
                   -k2*X[2]+k2*X[0]])
  
# Puntos críticos y condiciones inicialess
X_f0=np.array([0.0  , 0.0  , 0.0  , 0.0  ])
X0=np.array([1.0  , 0.0  ,4.0  , 0.0  ]) 
print('Puntos criticos del sistema para los valores dados')
print('X_f0=   ',X_f0)
print(all(dX_dt(X_f0) == np.zeros(4) ))
C_sol=la.solve(X,-C)
print(C_sol)

# Solución
t=np.linspace(0,50,1000)
X,infodict=integrate.odeint(dX_dt,X0,t,full_output=True)
infodict['message']
# Out:
# La matriz es
# [[  0.   1.   0.   0.]
#  [-10.  -0.   4.   0.]
#  [  0.   0.   0.   1.]
#  [  4.   0.  -4.  -0.]]
#
# Puntos criticos del sistema para los valores dados
# X_f0=    [0. 0. 0. 0.]
# True
# [[1.]
#  [0.]
#  [2.]
#  [0.]]
# 'Integration successful.'

# %%
x1, x3, x2, x4 =X.T+C_sol
f1 = plt.figure();
plt.figure(figsize=(20, 12)); 
plt.plot(t, x1,'r', label='Masa 1',);
plt.plot(t, x2, 'b', label='Masa 2',);
plt.grid();
plt.legend(loc='best');
plt.xlabel('T');
plt.ylabel('Posición');
plt.title('Masa contra t');
plt.show();

# %%
values  = np.linspace(1, 100, 1) # posición de X0 entre X_f0 y X_f1
vcolors = plt.cm.cividis(np.linspace(0.3, 1., len(values))) # colores para cada trayectoria
plt.figure(figsize=(20, 12)); 

# grafica las trayectorias
#-------------------------------------------------------
for v, col in zip(values, vcolors):
    X0 = v * X_f0                             
    # punto inicial
    X = integrate.odeint( dX_dt, X0, t)         
    # Integración para cada condición inicial
    plt.plot( X[:,0], X[:,2], lw=3.5*v, color=col,
             label='X0=(%.f, %.f)' % ( X0[0], X0[2]) )
ymax = plt.ylim(ymin=0)[1]
xmax = plt.xlim(xmin=0)[1]

for v, col in zip(values, vcolors):
    X0 = v * X_f0                             
    # punto inicial
    X = integrate.odeint( dX_dt, X0, t)         
    # Integración para cada condición inicial
    plt.plot( X[:,1], X[:,3], lw=3.5*v, color=col,
             label='X0=(%.f, %.f)' % ( X0[1], X0[3]) )
y2max= plt.ylim(ymin=0)[1]
x2max= plt.xlim(xmin=0)[1]

# define una malla y calcula la pendiente (dirección) en cada punto
#-------------------------------------------------------
nb_points   = 30
x = np.linspace(0, xmax, nb_points)
y = np.linspace(0, ymax, nb_points)
x2 = np.linspace(0, x2max, nb_points)
y2 = np.linspace(0, y2max, nb_points)

#Mallas
X1 , Y1 = np.meshgrid(x, y)     
X2 , Y2 = np.meshgrid(x2, y2)                  
# Tasa de crecimiento
DX1, DY1, DX2, DY2 = dX_dt([X1, Y1, X2  , Y2]) 
M = (np.hypot(DX1, DY1))  # distancia euclideana 
M[ M == 0] = 1.           # Evita divisiones entre 0 
DX1 /= M                  # Normaliza el tamaño de cada flecha
DY1 /= M                  # Normaliza el tamaño de cada flecha
# Dibujar los campos de direcciones usando la función quiver de Matplotlib 
# EL color de las flechas indica la rapidez de crecimiento
#-------------------------------------------------------
plt.title('Plano Fase: Trayectorias y campo de direcciones - Punto crítico (0,0)')
Q = plt.quiver(X1, Y1, DX1, DY1, M, pivot='mid', cmap=plt.cm.jet)
plt.xlabel('X1')
plt.ylabel('X2')
plt.legend(loc='best')
plt.grid()
plt.xlim(0, xmax)
plt.ylim(0, ymax)
plt.show()

# %% [markdown]
# ## **10.3**

# %% [markdown]
# Igual que el caso anterior pero, con fricción: $b_1=0.1, b_2=0.2$

# %%
# Constantes
k1=6.
k2=4.
b1=0.1
b2=0.2

# Matriz
X=np.array([[0,1,0,0],[-k1-k2,-b1,k2,0],[0,0,0,1],[k2,0,-1*k2,-1*b2]])
print('La matriz es ')
print(X)

C=np.array([[0],[2],[0],[4]])
def dX_dt(X,t=0):
  return np.array([X[1], 
                   (-k1-k2)*X[0] -b1*X[1] +k2*X[2],  
                   X[3],   
                   -k2*X[2]+k2*X[0]])
  
# Puntos críticos y condiciones inicialess
X_f0=np.array([0.0  , 0.0  , 0.0  , 0.0  ])
X0=np.array([1.0  , 0.0  ,4.0  , 0.0  ]) 
print('Puntos criticos del sistema para los valores dados')
print('X_f0=   ',X_f0)
print(all(dX_dt(X_f0) == np.zeros(4) ))
C_sol=la.solve(X,-C)
print(C_sol)

# Solución
t=np.linspace(0,50,1000)
X,infodict=integrate.odeint(dX_dt,X0,t,full_output=True)
infodict['message']
# Out:
# La matriz es
# [[  0.    1.    0.    0. ]
#  [-10.   -0.1   4.    0. ]
#  [  0.    0.    0.    1. ]
#  [  4.    0.   -4.   -0.2]]
# Puntos criticos del sistema para los valores dados
# X_f0=    [0. 0. 0. 0.]
# True
# [[1.]
#  [0.]
#  [2.]
#  [0.]]
# 'Integration successful.'

# %%
x1, x3, x2, x4 =X.T+C_sol
f1 = plt.figure();
plt.figure(figsize=(20, 12)); 
plt.plot(t, x1,'r', label='Masa 1',);
plt.plot(t, x2, 'b', label='Masa 2',);
plt.grid();
plt.legend(loc='best');
plt.xlabel('T');
plt.ylabel('Posición');
plt.title('Masa contra t');
plt.show();

# %%
values  = np.linspace(1, 100, 1) # posición de X0 entre X_f0 y X_f1
vcolors = plt.cm.cividis(np.linspace(0.3, 1., len(values))) # colores para cada trayectoria
plt.figure(figsize=(20, 12)); 

# grafica las trayectorias
#-------------------------------------------------------
for v, col in zip(values, vcolors):
    X0 = v * X_f0                             
    # punto inicial
    X = integrate.odeint( dX_dt, X0, t)         
    # Integración para cada condición inicial
    plt.plot( X[:,0], X[:,2], lw=3.5*v, color=col,
             label='X0=(%.f, %.f)' % ( X0[0], X0[2]) )
ymax = plt.ylim(ymin=0)[1]
xmax = plt.xlim(xmin=0)[1]

for v, col in zip(values, vcolors):
    X0 = v * X_f0                             
    # punto inicial
    X = integrate.odeint( dX_dt, X0, t)         
    # Integración para cada condición inicial
    plt.plot( X[:,1], X[:,3], lw=3.5*v, color=col,
             label='X0=(%.f, %.f)' % ( X0[1], X0[3]) )
y2max= plt.ylim(ymin=0)[1]
x2max= plt.xlim(xmin=0)[1]

# define una malla y calcula la pendiente (dirección) en cada punto
#-------------------------------------------------------
nb_points   = 30
x = np.linspace(0, xmax, nb_points)
y = np.linspace(0, ymax, nb_points)
x2 = np.linspace(0, x2max, nb_points)
y2 = np.linspace(0, y2max, nb_points)

#Mallas
X1 , Y1 = np.meshgrid(x, y)     
X2 , Y2 = np.meshgrid(x2, y2)                  
# Tasa de crecimiento
DX1, DY1, DX2, DY2 = dX_dt([X1, Y1, X2  , Y2]) 
M = (np.hypot(DX1, DY1))  # distancia euclideana 
M[ M == 0] = 1.           # Evita divisiones entre 0 
DX1 /= M                  # Normaliza el tamaño de cada flecha
DY1 /= M                  # Normaliza el tamaño de cada flecha
# Dibujar los campos de direcciones usando la función quiver de Matplotlib 
# EL color de las flechas indica la rapidez de crecimiento
#-------------------------------------------------------
plt.title('Plano Fase: Trayectorias y campo de direcciones - Punto crítico (0,0)')
Q = plt.quiver(X1, Y1, DX1, DY1, M, pivot='mid', cmap=plt.cm.jet)
plt.xlabel('X1')
plt.ylabel('X2')
plt.legend(loc='best')
plt.grid()
plt.xlim(0, xmax)
plt.ylim(0, ymax)
plt.show()
